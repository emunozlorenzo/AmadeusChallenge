# %% [markdown]
# ## Top 10 arrival airports in the world in 2013 (using the bookings file)
#
# Arrival airport is the column arr_port. It is the IATA code for the airport
#
# To get the total number of passengers for an airport, you can sum the "pax" column, grouping by arr_port.
#
# Note that there is negative pax. That corresponds to cancelations. So to get the total number of passengers that have actually booked, you should sum including the negatives (that will remove the canceled bookings).
#
# Print the top 10 arrival airports in the standard output, including the number of passengers.
#
# Bonus point: Get the name of the city or airport corresponding to that airport (programatically, we suggest to have a look at [neobase in Github](https://github.com/alexprengere/neobase))
#
# Bonus point: Solve this problem using pandas (instead of any other approach)

# %% [markdown]
# Suggestion: follow the below plan of action:
#
# * Get familiar with the data
# * Select columns of interest
# * Decide what to do with NaNs
#
# * Make processing plan
# * Develop code that works with a sample
#
# * Adjust the code to work with Big data
# * Test big data approach on a sample
#
# * Run program with big data

# %% [markdown]
# ## 1) Get familiar with data

# %%
# Where am i?

! pwd
# Out:
# /home/dsc/Repos/AmadeusChallenge

# %%
# Let's go to the right folder (/home/dsc/Data/challenge)

% cd /home/dsc/Data/challenge
# Out:
# /home/dsc/Data/challenge

# %%
# What can we find inside?

! ls -laS
# Out:
# total 1017196
# -rwxr-x--- 1 dsc dsc 554970628 mar 13  2018 bookings.csv.bz2
# -rwxr-x--- 1 dsc dsc 483188920 mar 13  2018 searches.csv.bz2
# -rw-r--r-- 1 dsc dsc   2119069 ene 30 20:12 bookings_sample.csv
# -rw-r--r-- 1 dsc dsc    910597 ene 30 20:12 searches_sample.csv
# -rw-r--r-- 1 dsc dsc    270148 ene 30 20:12 bookings_sample.csv.bz2
# -rw-r--r-- 1 dsc dsc    120210 ene 30 20:12 searches_sample.csv.bz2
# drwxr-x--- 2 dsc dsc      4096 ene 30 20:12 .
# drwxr-x--- 8 dsc dsc      4096 ene 25 10:46 ..

# %% [markdown]
# ### What if we dont want to read the whole file?

# %% [markdown]
# Options:
#
# * prepare the sample
#
# * read_csv with nrows option

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [raw]
# Commands for obtaining data info:
#     b.shape  - object
#     b.info()
#
#     b.columns
#     b.columns.to_list()
#     list(b.columns)
#
#     b.head() -function
#     b.sample()
#
#     #pd.set_option('display.max_columns', 100)
#     pd.set_option('display.max_columns', None)
#
#     b.describe()
#     b.describe(include='all')
#     df.dtypes
#
#     b.isnull().sum()
#     non_null_counts = b.count()

# %%
# Reading the CSV Sample

bookings = pd.read_csv('bookings_sample.csv', sep='^')
bookings.head()
# Out:
#    act_date             source  pos_ctry                          pos_iata  \
# 0  2013-03-05 00:00:00  1A      DE        a68dd7ae953c8acfb187a1af2dcbe123
# 1  2013-03-26 00:00:00  1A      US        e612b9eeeee6f17f42d9b0d3b79e75ca
# 2  2013-03-26 00:00:00  1A      US        e612b9eeeee6f17f42d9b0d3b79e75ca
# 3  2013-03-26 00:00:00  1A      AU        0f984b3bb6bd06661c95529bbd6193bc
# 4  2013-03-26 00:00:00  1A      AU        0f984b3bb6bd06661c95529bbd6193bc
#
#                           pos_oid                      rloc            \
# 0  1a11ae49fcbf545fd2afc1a24d88d2b7  ea65900e72d71f4626378e2ebd298267
# 1  7437560d8f276d6d05eeb806d9e7edee  737295a86982c941f1c2da9a46a14043
# 2  7437560d8f276d6d05eeb806d9e7edee  737295a86982c941f1c2da9a46a14043
# 3  36472c6dbaf7afec9136ac40364e2794  5ecf00fdcbcec761c43dc7285253d0c1
# 4  36472c6dbaf7afec9136ac40364e2794  5ecf00fdcbcec761c43dc7285253d0c1
#
#    cre_date             duration  distance  dep_port    ...      \
# ...

# %%
# How many columns can i see?

pd.options.display.max_columns
# Out:
# 20

# %%
# Ok, but i want to see all the columns (38)

pd.set_option('display.max_columns',50)

# Then the result will be 50 columns

pd.options.display.max_columns
# Out:
# 50

# %%
bookings.head()
# Out:
#    act_date             source  pos_ctry                          pos_iata  \
# 0  2013-03-05 00:00:00  1A      DE        a68dd7ae953c8acfb187a1af2dcbe123
# 1  2013-03-26 00:00:00  1A      US        e612b9eeeee6f17f42d9b0d3b79e75ca
# 2  2013-03-26 00:00:00  1A      US        e612b9eeeee6f17f42d9b0d3b79e75ca
# 3  2013-03-26 00:00:00  1A      AU        0f984b3bb6bd06661c95529bbd6193bc
# 4  2013-03-26 00:00:00  1A      AU        0f984b3bb6bd06661c95529bbd6193bc
#
#                           pos_oid                      rloc            \
# 0  1a11ae49fcbf545fd2afc1a24d88d2b7  ea65900e72d71f4626378e2ebd298267
# 1  7437560d8f276d6d05eeb806d9e7edee  737295a86982c941f1c2da9a46a14043
# 2  7437560d8f276d6d05eeb806d9e7edee  737295a86982c941f1c2da9a46a14043
# 3  36472c6dbaf7afec9136ac40364e2794  5ecf00fdcbcec761c43dc7285253d0c1
# 4  36472c6dbaf7afec9136ac40364e2794  5ecf00fdcbcec761c43dc7285253d0c1
#
#    cre_date             duration  distance  dep_port  dep_city  dep_ctry  \
# ...

# %%
# Column Type

bookings.dtypes
# Out:
# act_date               object
# source                 object
# pos_ctry               object
# pos_iata               object
# pos_oid                object
# rloc                   object
# cre_date               object
# duration                int64
# distance                int64
# dep_port               object
# dep_city               object
# dep_ctry               object
# arr_port               object
# arr_city               object
# arr_ctry               object
# lst_port               object
# lst_city               object
# lst_ctry               object
# brd_port               object
# brd_city               object
# brd_ctry               object
# off_port               object
# off_city               object
# off_ctry               object
# mkt_port               object
# mkt_city               object
# mkt_ctry               object
# intl                    int64
# route                  object
# carrier                object
# bkg_class              object
# ...

# %%
# Some Statistics of Int64 Columns

bookings.describe()
# Out:
#             duration      distance         intl          pax    year   month
# count    4999.000000   4999.000000  4999.000000  4999.000000  4999.0  4999.0
# mean    21165.771154    454.354471     0.593719     0.497099  2013.0     3.0
# std     44172.823174   1801.837863     0.491187     1.677101     0.0     0.0
# min        59.000000      0.000000     0.000000    -8.000000  2013.0     3.0
# 25%      3346.000000      0.000000     0.000000    -1.000000  2013.0     3.0
# 50%      7452.000000      0.000000     1.000000     1.000000  2013.0     3.0
# 75%     18993.000000      0.000000     1.000000     1.000000  2013.0     3.0
# max    488131.000000  18481.000000     1.000000    21.000000  2013.0     3.0

# %%
# Null Values? There are not null values

bookings.isna().sum()
# Out:
# act_date               0
# source                 0
# pos_ctry               0
# pos_iata               0
# pos_oid                0
# rloc                   0
# cre_date               0
# duration               0
# distance               0
# dep_port               0
# dep_city               0
# dep_ctry               0
# arr_port               0
# arr_city               0
# arr_ctry               0
# lst_port               0
# lst_city               0
# lst_ctry               0
# brd_port               0
# brd_city               0
# brd_ctry               0
# off_port               0
# off_city               0
# off_ctry               0
# mkt_port               0
# mkt_city               0
# mkt_ctry               0
# intl                   0
# route                  0
# carrier                0
# bkg_class              0
# cab_class              0
# brd_time               0
# off_time               0
# pax                    0
# year                   0
# month                  0
# ...

# %% [markdown]
# Clean the column names

# %%
# Renaming Columns

bookings.rename(columns={'arr_port':'Arrival_Airport','pax':'Pax','year':'Year'}, inplace=True)
bookings.head()
# Out:
#    act_date             source  pos_ctry                          pos_iata  \
# 0  2013-03-05 00:00:00  1A      DE        a68dd7ae953c8acfb187a1af2dcbe123
# 1  2013-03-26 00:00:00  1A      US        e612b9eeeee6f17f42d9b0d3b79e75ca
# 2  2013-03-26 00:00:00  1A      US        e612b9eeeee6f17f42d9b0d3b79e75ca
# 3  2013-03-26 00:00:00  1A      AU        0f984b3bb6bd06661c95529bbd6193bc
# 4  2013-03-26 00:00:00  1A      AU        0f984b3bb6bd06661c95529bbd6193bc
#
#                           pos_oid                      rloc            \
# 0  1a11ae49fcbf545fd2afc1a24d88d2b7  ea65900e72d71f4626378e2ebd298267
# 1  7437560d8f276d6d05eeb806d9e7edee  737295a86982c941f1c2da9a46a14043
# 2  7437560d8f276d6d05eeb806d9e7edee  737295a86982c941f1c2da9a46a14043
# 3  36472c6dbaf7afec9136ac40364e2794  5ecf00fdcbcec761c43dc7285253d0c1
# 4  36472c6dbaf7afec9136ac40364e2794  5ecf00fdcbcec761c43dc7285253d0c1
#
#    cre_date             duration  distance  dep_port  dep_city  dep_ctry  \
# ...

# %% [markdown]
# ## 2) Select the columns of interest

# %%
top10 = bookings[['Arrival_Airport','Pax','Year']]
top10.head()
# Out:
#   Arrival_Airport  Pax  Year
# 0        LHR        -1  2013
# 1        CLT         1  2013
# 2        CLT         1  2013
# 3        SVO         1  2013
# 4        SVO         1  2013

# %% [markdown]
# ## 3) What to do with NaN?

# %% [markdown]
# In the sample everything might be ok, but we should prepare for NaN case

# %%
# Null Values?

top10.isnull().sum()
# Out:
# Arrival_Airport    0
# Pax                0
# Year               0
# dtype: int64

# %%
# We can take two options: 
#    - Remove NaN values
#    - Fill Nan values

top10.dropna(inplace= True)
# Out:
# /home/dsc/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """

# %% [markdown]
# ## 4) Make processing plan
# 1) get only the bookings from 2013
#
# 2) group by arr_port, sum
#
# 3) sort
#
# 4) get top 10

# %% [markdown]
# #### 4.1) Get only the booking from 2013

# %%
# Shape of my current file

top10.shape
# Out:
# (4999, 3)

# %%
# top10 and top10_2013 have the same number of rows. Conclusion: All the rows match 2013

top10_2013 = top10[top10['Year'] == 2013]
top10_2013.shape
# Out:
# (4999, 3)

# %% [markdown]
# #### 4.2) group by arr_port, sum

# %%
top10_2013.groupby('Arrival_Airport')['Pax'].sum().sort_values(ascending= False).head(10)
# Out:
# Arrival_Airport
# DCA         60
# LAX         54
# DEN         53
# SFO         53
# ORD         52
# MCO         42
# LGA         41
# PVG         39
# HKG         38
# JFK         35
# Name: Pax, dtype: int64

# %% [markdown]
# ## 5) Adjust the code to work with Big data
#
#
# Hint: check out https://pandas.pydata.org/pandas-docs/stable/io.html#io-chunking

# %%
chunksize = 1000
df = pd.DataFrame()
for chunk in pd.read_csv('bookings_sample.csv',sep='^' ,chunksize=chunksize):
       print(chunk.groupby('arr_port')['pax'].sum().sort_values(ascending=False).head())
# Out:
# arr_port
# DCA         50
# JFK         14
# FLL         13
# PVG         13
# SVO         12
# Name: pax, dtype: int64
# arr_port
# JFK         18
# ATL         13
# DXB         13
# SFO         13
# PHL         12
# Name: pax, dtype: int64
# arr_port
# DEN         23
# MCO         22
# USM         18
# MEM         14
# ORD         13
# Name: pax, dtype: int64
# arr_port
# LIN         18
# LAX         12
# DEN         12
# DCA         12
# PVG         12
# Name: pax, dtype: int64
# arr_port
# ORD         19
# PEK         18
# PMI         16
# LAX         15
# CDG         14
# Name: pax, dtype: int64

# %% [markdown]
# #### Now we need to put together the results from all the chunks

# %% [markdown]
# Options:
#
# * df.append()
#
# * pd.concat()
#
#
# pd.concat handles several DataFrames in one go, while df.append creates a new DataFrame every time we call it.

# %%
df = pd.read_csv ('bookings_sample.csv', sep = '^', usecols = ['arr_port', 'pax', 'year'],chunksize = 1000)

sum_chunks = pd.DataFrame()

k=0
for chunk in df:
    k += 1
    print ("Chunk:%d size of chunk %d"% (k,len(chunk)))
    filtered_chunk = chunk[chunk['year'] == 2013]
    filtered_chunk.drop ('year', axis =1, inplace=True)
    arr_ports = filtered_chunk.groupby ('arr_port')
    chunk_result = arr_ports.sum()
    sum_chunks = sum_chunks.append(chunk_result)
sum_chunks.head()
# Out:
# Chunk:1 size of chunk 1000
# Chunk:2 size of chunk 1000
# Chunk:3 size of chunk 1000
# Chunk:4 size of chunk 1000
# Chunk:5 size of chunk 999
#           pax
# arr_port
# ACC         6
# ADD         2
# AGP         6
# ALA         2
# ALC         4

# %%
top10_ports_2013 = sum_chunks.groupby(sum_chunks.index).pax.sum().sort_values(ascending = False).head(10).reset_index()
top10_ports_2013
# Out:
#    arr_port  pax
# 0  DCA        60
# 1  LAX        54
# 2  DEN        53
# 3  SFO        53
# 4  ORD        52
# 5  MCO        42
# 6  LGA        41
# 7  PVG        39
# 8  HKG        38
# 9  JFK        35

# %% [markdown]
# ## Complete Solution

# %%
df = pd.read_csv ('bookings.csv.bz2', sep = '^', usecols = ['arr_port', 'pax', 'year'],chunksize = 1000000)

sum_chunks = pd.DataFrame()

k=0
for chunk in df:
    k += 1
    filtered_chunk = chunk[chunk['year'] == 2013]
    filtered_chunk.drop ('year', axis =1, inplace=True)
    nulls = filtered_chunk['pax'].isnull().sum()
    print ("Chunk %d: size of chunk %d, Null Values: %s"% (k,len(chunk),nulls))
    filtered_chunk.dropna(inplace=True)
    arr_ports = filtered_chunk.groupby ('arr_port')
    chunk_result = arr_ports.sum()
    sum_chunks = sum_chunks.append(chunk_result)
top10_ports_2013 = sum_chunks.groupby(sum_chunks.index).pax.sum().sort_values(ascending = False).head(10).reset_index()
top10_ports_2013.columns=['Arrival_Airport','Pax']
top10_ports_2013
# Out:
# Chunk 1: size of chunk 1000000, Null Values: 0
# Chunk 2: size of chunk 1000000, Null Values: 0
# Chunk 3: size of chunk 1000000, Null Values: 0
# Chunk 4: size of chunk 1000000, Null Values: 0
# Chunk 5: size of chunk 1000000, Null Values: 0
# /home/dsc/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':
# Chunk 6: size of chunk 1000000, Null Values: 0
# /home/dsc/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if sys.path[0] == '':
# Chunk 7: size of chunk 1000000, Null Values: 0
# ...

# %%
top10_ports_2013.set_index('Arrival_Airport').plot(kind='bar',title='TOP 10 ARRIVAL AIRPORTS 2013',color='green',alpha=0.5)
plt.xlabel('Arrival Airports')
plt.ylabel('Pax');
plt.grid(True,axis='y',alpha=0.2)

# %% [markdown]
# ### Airport Names
#
# Using [neobase](https://github.com/alexprengere/neobase), the successor to GeoBases. It's a referential data library that particularly focuses on airports.

# %% [markdown]
# ### An Alternative
#
# Chunking with pandas DataFrames is a very general technique that can be applied to lots of datasets that don't fit in memory. It is useful to know because it's very widely applicable.
#
# However, very often small optimizations and tricks will allow us to get the job done, and they may be even quicker.
#
# In this case, the dataset is pretty close to fitting in memory, so just using the usecols argument to read_csv can get us there. It will only load the three relevant columns to start with.
